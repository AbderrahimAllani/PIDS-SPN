# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.12.2 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 d:\downloads\NewAndEnhancedWork2\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 90.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\detect\predict7
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/detect/predict/dog.jpeg', height=600)

# %%
from roboflow import Roboflow

# Read API key from the text file
with open(r"C:\Users\abder\OneDrive\Desktop\api_key.txt", "r") as file:
    api_key = file.read().strip()

# Initialize Roboflow with the API key
rf = Roboflow(api_key=api_key)

# Continue with your code
project = rf.workspace("thev").project("document-detection-aoemj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.2.9 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.12.2 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# ...

# %%
from IPython.display import Image
# Make sure the path to the image is correct.
# If the path is incorrect or the file does not exist, it won't display.
image_path = 'runs/detect/train8/confusion_matrix.png'
Image(filename=image_path, width=600)

# %%
from IPython.display import Image
# Make sure the path to the image is correct.
# If the path is incorrect or the file does not exist, it won't display.
image_path = 'runs/detect/train8/results.png'
Image(filename=image_path, width=600)

# %%
# !yolo task=detect mode=val model=D:/downloads/NewAndEnhancedWork2/runs/detect/train8/weights/best.pt data=D:/downloads/NewAndEnhancedWork2/Document-detection-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196  Python-3.12.2 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning D:\downloads\NewAndEnhancedWork2\Document-detection-1\valid\labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
# val: Scanning D:\downloads\NewAndEnhancedWork2\Document-detection-1\valid\labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:08<00:00,  8.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:08<00:00,  8.49s/it]
# ...

# %%
# !yolo task=detect mode=predict model=D:/downloads/NewAndEnhancedWork2/runs/detect/train8/weights/best.pt conf=0.25 source=D:/downloads/NewAndEnhancedWork2/Document-detection-1/test/images save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.12.2 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/7 D:\downloads\NewAndEnhancedWork2\Document-detection-1\test\images\WhatsApp-Image-2024-03-15-at-11-45-44-1-_jpeg.rf.e047f8a22369338f7442765e08b56272.jpg: 800x800 1 paper-document-, 25.8ms
# image 2/7 D:\downloads\NewAndEnhancedWork2\Document-detection-1\test\images\WhatsApp-Image-2024-03-15-at-12-08-41-1-_jpeg.rf.1f18efc8a550718ada2030a2d14d4657.jpg: 800x800 1 paper-document-, 26.3ms
# image 3/7 D:\downloads\NewAndEnhancedWork2\Document-detection-1\test\images\WhatsApp-Image-2024-03-15-at-12-20-38_jpeg.rf.ecef8da039e3b387f5e0db2450743db7.jpg: 800x800 1 paper-document-, 25.9ms
# image 4/7 D:\downloads\NewAndEnhancedWork2\Document-detection-1\test\images\WhatsApp-Image-2024-03-15-at-12-27-02_jpeg.rf.bcc71e4d2d84cda6d2f0b8e222c6c5ef.jpg: 800x800 1 paper-document-, 25.1ms
# ...
